# %% [markdown]
# # Homework 3: Table Manipulation and Visualization
#
# Please complete this notebook by filling in the cells provided.

# %% [markdown]
# **Helpful Resource:**
# - [Python Reference](http://data8.org/sp22/python-reference.html): Cheat sheet of helpful array & table methods.
#
# **Recommended Reading**:
# * [Visualization](https://inferentialthinking.com/chapters/07/Visualization.html)

# %% [markdown]
# For all problems that you must write explanations and sentences for, you **must** provide your answer in the designated space. **Moreover, throughout this homework and all future ones, please be sure to not re-assign variables throughout the notebook!** For example, if you use `max_temperature` in your answer to one question, do not reassign it later on. Otherwise, you will fail tests that you thought you were passing previously!
#
#
#
# Directly sharing answers is not okay, but discussing problems with other students is encouraged.
#
# You should start early so that you have time to get help if you're stuck.

# %%
# Don't change this cell; just run it. 

import numpy as np
from datascience import *
import warnings
warnings.simplefilter('ignore', FutureWarning)

# These lines do some fancy plotting magic.\n",
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## 1. Unemployment

# %% [markdown]
# The Great Recession of 2008-2009 was a period of economic decline observed globally, with scale and timing varying from country to country. In the United States, it resulted in a rapid rise in unemployment that affected industries and population groups to different extents.
#
# The Federal Reserve Bank of St. Louis publishes data about jobs in the US.  Below, we've loaded data on unemployment in the United States. There are many ways of defining unemployment, and our dataset includes two notions of the unemployment rate:
#
# 1. Among people who are able to work and are looking for a full-time job, the percentage who can't find a job.  This is called the Non-Employment Index, or NEI.
# 2. Among people who are able to work and are looking for a full-time job, the percentage who can't find any job *or* are only working at a part-time job.  The latter group is called "Part-Time for Economic Reasons", so the acronym for this index is NEI-PTER.  (Economists are great at marketing.)
#
# The source of the data is [here](https://fred.stlouisfed.org/categories/33509).

# %% [markdown]
# **Question 1.** The data are in a CSV file called `unemployment.csv`.  Load that file into a table called `unemployment`.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
unemployment = Table.read_table("/Users/camel/Downloads/unemployment.csv") #upload the file
unemployment #show table
# Out:
# Date       | NEI     | NEI-PTER
# 1994-01-01 | 10.0974 | 11.172
# 1994-04-01 | 9.6239  | 10.7883
# 1994-07-01 | 9.3276  | 10.4831
# 1994-10-01 | 9.1071  | 10.2361
# 1995-01-01 | 8.9693  | 10.1832
# 1995-04-01 | 9.0314  | 10.1071
# 1995-07-01 | 8.9802  | 10.1084
# 1995-10-01 | 8.9932  | 10.1046
# 1996-01-01 | 9.0002  | 10.0531
# 1996-04-01 | 8.9038  | 9.9782
# ... (80 rows omitted)

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 2.** Sort the data in descending order by NEI, naming the sorted table `by_nei`.  Create another table called `by_nei_pter` that's sorted in descending order by NEI-PTER instead.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.# BEGIN SOLUTION

# %%
by_nei = unemployment.sort('NEI', descending=True) #sort the nei column in descending order
by_nei #print the new table
# Out:
# Date       | NEI     | NEI-PTER
# 2009-10-01 | 10.9698 | 12.8557
# 2010-01-01 | 10.9054 | 12.7311
# 2009-07-01 | 10.8089 | 12.7404
# 2009-04-01 | 10.7082 | 12.5497
# 2010-04-01 | 10.6597 | 12.5664
# 2010-10-01 | 10.5856 | 12.4329
# 2010-07-01 | 10.5521 | 12.3897
# 2011-01-01 | 10.5024 | 12.3017
# 2011-07-01 | 10.4856 | 12.2507
# 2011-04-01 | 10.4409 | 12.247
# ... (80 rows omitted)

# %%
by_nei_pter = unemployment.sort('NEI-PTER', descending=True) #sort the nei pter column by descending order
by_nei_pter #print the new table
# Out:
# Date       | NEI     | NEI-PTER
# 2009-10-01 | 10.9698 | 12.8557
# 2009-07-01 | 10.8089 | 12.7404
# 2010-01-01 | 10.9054 | 12.7311
# 2010-04-01 | 10.6597 | 12.5664
# 2009-04-01 | 10.7082 | 12.5497
# 2010-10-01 | 10.5856 | 12.4329
# 2010-07-01 | 10.5521 | 12.3897
# 2011-01-01 | 10.5024 | 12.3017
# 2011-07-01 | 10.4856 | 12.2507
# 2011-04-01 | 10.4409 | 12.247
# ... (80 rows omitted)

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 3.** Use `take` to make a table containing the data for the 11 quarters when NEI was greatest.  Call that table `greatest_nei`.
#
# `greatest_nei` should be sorted in descending order of `NEI`. Note that each row of `unemployment` represents a quarter.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
greatest_nei = unemployment.sort('NEI', descending=True).take(np.arange(11)) #sort in descending order + take the top 11 rows
greatest_nei #show new table
# Out:
# Date       | NEI     | NEI-PTER
# 2009-10-01 | 10.9698 | 12.8557
# 2010-01-01 | 10.9054 | 12.7311
# 2009-07-01 | 10.8089 | 12.7404
# 2009-04-01 | 10.7082 | 12.5497
# 2010-04-01 | 10.6597 | 12.5664
# 2010-10-01 | 10.5856 | 12.4329
# 2010-07-01 | 10.5521 | 12.3897
# 2011-01-01 | 10.5024 | 12.3017
# 2011-07-01 | 10.4856 | 12.2507
# 2011-04-01 | 10.4409 | 12.247
# ... (1 rows omitted)

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 4.** It's believed that many people became PTER (recall: "Part-Time for Economic Reasons") in the "Great Recession" of 2008-2009.  NEI-PTER is the percentage of people who are unemployed (included in the NEI) plus the percentage of people who are PTER.
#
# Compute an array containing the percentage of people who were PTER in each quarter.  (The first element of the array should correspond to the first row of `unemployment`, and so on.)
#
# *Note:* Use the original `unemployment` table for this.

# %% [raw]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
nei_percent = unemployment.column('NEI') #extract nei column
pter_percent = unemployment.column('NEI-PTER') #extract nei pter column
nei_pter = nei_percent + pter_percent #add the two percentages
nei_pter #print the array
# Out:
# array([ 21.2694,  20.4122,  19.8107,  19.3432,  19.1525,  19.1385,
#         19.0886,  19.0978,  19.0533,  18.882 ,  18.6258,  18.3855,
#         18.4027,  18.0285,  17.5994,  17.4404,  17.2185,  16.8915,
#         17.1839,  16.9503,  16.6074,  17.0271,  16.616 ,  16.3242,
#         15.9507,  16.0953,  16.1373,  16.0961,  16.2539,  16.8393,
#         17.1306,  18.3487,  18.9419,  18.8219,  18.6719,  18.3943,
#         18.7951,  18.9661,  19.1079,  18.9568,  18.6421,  18.4588,
#         18.365 ,  18.367 ,  18.107 ,  17.9506,  17.7213,  17.7242,
#         17.467 ,  17.5002,  17.3431,  17.2182,  17.1386,  17.4206,
#         17.3179,  17.4953,  17.6801,  18.1114,  19.0553,  19.9445,
#         22.2832,  23.2579,  23.5493,  23.8255,  23.6365,  23.2261,
#         22.9418,  23.0185,  22.8041,  22.6879,  22.7363,  22.4501,
#         21.866 ,  21.7155,  21.7828,  21.3969,  21.8239,  21.2871,
#         20.9309,  20.9014,  20.0678,  19.8129,  19.713 ,  19.3971,
#         19.1945,  18.9869,  18.6013,  18.5035,  18.0504,  18.2546])

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 5.** Add `pter` as a column to `unemployment` (name the column `PTER`) and sort the resulting table by that column in descending order.  Call the resulting table `by_pter`.
#
# Try to do this with a single line of code, if you can.

# %% [raw]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
by_pter = unemployment.with_column('PTER', unemployment.column('NEI') + unemployment.column('NEI-PTER')).sort('PTER', descending=True)
#for the line above: adds percentages between NEI and NEI-PTER, then puts those new numbers into the PTER column
by_pter #prints the table with the new column
# Out:
# Date       | NEI     | NEI-PTER | PTER
# 2009-10-01 | 10.9698 | 12.8557  | 23.8255
# 2010-01-01 | 10.9054 | 12.7311  | 23.6365
# 2009-07-01 | 10.8089 | 12.7404  | 23.5493
# 2009-04-01 | 10.7082 | 12.5497  | 23.2579
# 2010-04-01 | 10.6597 | 12.5664  | 23.2261
# 2010-10-01 | 10.5856 | 12.4329  | 23.0185
# 2010-07-01 | 10.5521 | 12.3897  | 22.9418
# 2011-01-01 | 10.5024 | 12.3017  | 22.8041
# 2011-07-01 | 10.4856 | 12.2507  | 22.7363
# 2011-04-01 | 10.4409 | 12.247   | 22.6879
# ... (80 rows omitted)

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 6.** Create a line plot of PTER over time. To do this, create a new table called `pter_over_time` by making a copy of the `unemployment` table and adding two new columns: `Year` and `PTER` using the `year` array and the `pter` array, respectively. Then, generate a line plot using one of the table methods you've learned in class.
#
# The order of the columns matter for our correctness tests, so be sure `Year` comes before `PTER`.
#
# *Note:* When constructing `pter_over_time`, do not just add the `year` column to the `by_pter` table. Please follow the directions in the question above.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
import matplotlib.pyplot as plt
import numpy as np

year = np.array([x[2:4] for x in unemployment.column('Date')]) #get year from date column + just shows last 2 digits to make less cluttered

#create pter_over_time by copying the unemployment table and adding Year and PTER columns
pter_over_time = unemployment.with_columns(
    'Year', year,  #add the Year column from the extracted year array
    'PTER', unemployment.column('NEI-PTER') + unemployment.column('NEI')  #compute PTER column
)

#plot PTER over time
plt.plot(pter_over_time.column('Year'), pter_over_time.column('PTER'))
plt.xlabel('Year')
plt.ylabel('PTER')
plt.title('PTER Over Time')
plt.xticks(ticks=pter_over_time.column('Year')) #sets the x-axis labels to be last two digits of the year
plt.show()

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 7.** Were PTER rates high during the Great Recession (that is to say, were PTER rates particularly high in the years 2008 through 2011)? Assign `highPTER` to `True` if you think PTER rates were high in this period, or `False` if you think they weren't.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
highPTER = True #assigns highPTER to True as the graph shows PTER rates were high
print(highPTER) #print answer
# Out:
# True

# %% [markdown]
# END SOLUTION

# %% [markdown]
# ## 2. Birth Rates

# %% [markdown]
# The following table gives Census-based population estimates for each US state on both July 1, 2015 and July 1, 2016. The last four columns describe the components of the estimated change in population during this time interval. **For all questions below, assume that the word "states" refers to all 52 rows including Puerto Rico and the District of Columbia.**
#
# The data was taken from [here](http://www2.census.gov/programs-surveys/popest/datasets/2010-2016/national/totals/nst-est2016-alldata.csv). (Note: If it doesn't download for you when you click the link, please copy and paste it into your address bar!) If you want to read more about the different column descriptions, click [here](http://www2.census.gov/programs-surveys/popest/datasets/2010-2015/national/totals/nst-est2015-alldata.pdf).
#
# The raw data is a bit messy—run the cell below to clean the table and make it easier to work with.

# %%
# Don't change this cell; just run it.
pop = Table.read_table("/Users/camel/Downloads/nst-est2016-alldata.csv").where('SUMLEV', 40).select([1, 4, 12, 13, 27, 34, 62, 69])
pop = pop.relabeled('POPESTIMATE2015', '2015').relabeled('POPESTIMATE2016', '2016')
pop = pop.relabeled('BIRTHS2016', 'BIRTHS').relabeled('DEATHS2016', 'DEATHS')
pop = pop.relabeled('NETMIG2016', 'MIGRATION').relabeled('RESIDUAL2016', 'OTHER')
pop = pop.with_columns("REGION", np.array([int(region) if region != "X" else 0 for region in pop.column("REGION")]))
pop.set_format([2, 3, 4, 5, 6, 7], NumberFormatter(decimals=0)).show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>REGION</th> <th>NAME</th> <th>2015</th> <th>2016</th> <th>BIRTHS</th> <th>DEATHS</th> <th>MIGRATION</th> <th>OTHER</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>3     </td> <td>Alabama   </td> <td>4,853,875 </td> <td>4,863,300 </td> <td>58,556 </td> <td>52,405 </td> <td>3,874    </td> <td>-600  </td>
#         </tr>
#         <tr>
#             <td>4     </td> <td>Alaska    </td> <td>737,709   </td> <td>741,894   </td> <td>11,255 </td> <td>4,511  </td> <td>-2,557   </td> <td>-2    </td>
#         </tr>
#         <tr>
#             <td>4     </td> <td>Arizona   </td> <td>6,817,565 </td> <td>6,931,071 </td> <td>87,204 </td> <td>56,564 </td> <td>76,405   </td> <td>6,461 </td>
#         </tr>
#         <tr>
#             <td>3     </td> <td>Arkansas  </td> <td>2,977,853 </td> <td>2,988,248 </td> <td>37,936 </td> <td>30,581 </td> <td>3,530    </td> <td>-490  </td>
#         </tr>
#         <tr>
#             <td>4     </td> <td>California</td> <td>38,993,940</td> <td>39,250,017</td> <td>502,848</td> <td>273,850</td> <td>33,530   </td> <td>-6,451</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (47 rows omitted)</p>

# %% [markdown]
# **Question 1.** Assign `us_birth_rate` to the total US annual birth rate during this time interval. The annual birth rate for a year-long period is the total number of births in that period as a proportion of the total population size at the start of the time period.
#
# *Hint:* Which year corresponds to the start of the time period?

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
import math
us_birth_rate = (sum(pop.column('BIRTHS')))/(sum(pop.column('2015'))) #the data is from 2015-2016, divide sums
us_birth_rate #print result
# Out:
# 0.012276445416198907

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 2.** Assign `movers` to the number of states for which the **absolute value** of the **annual rate of migration** was higher than 1%. The annual rate of migration for a year-long period is the net number of migrations (in and out) as a proportion of the population size at the start of the period. The `MIGRATION` column contains estimated annual net migration counts by state.
#
# *Hint*: `migration_rates` should be a table and `movers` should be a number.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
migration_rates = pop.with_column('Migration Rate', abs(pop.column('MIGRATION')/pop.column('2015'))) #create new table for migration rates
movers = migration_rates.where('Migration Rate', are.above(0.01)).num_rows #filter for states with rates higher than 1%
movers #print result
# Out:
# 9

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 3.** Assign `west_births` to the total number of births that occurred in region 4 (the Western US).
#
# *Hint:* Make sure you double check the type of the values in the `REGION` column and appropriately filter (i.e. the types must match!).

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
west_births = sum(pop.where('REGION', are.equal_to(4)).column('BIRTHS')) #filter births in region 4
west_births #print result
# Out:
# 979657

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 4.** In the next question, you will be creating a visualization to understand the relationship between birth and death rates. The annual death rate for a year-long period is the total number of deaths in that period as a proportion of the population size at the start of the time period.
#
# What visualization is most appropriate to see if there is an association between birth and death rates during a given time interval?
#
# 1. Line Graph
# 2. Bar Chart
# 3. Scatter Plot
#
# Assign `visualization` below to the number corresponding to the correct visualization.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
visualization = 3 #scatter plots are best at showing the relationship between two variables with two axes
visualization #print result
# Out:
# 3

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 5.** In the code cell below, create a visualization that will help us determine if there is an association between birth rate and death rate during this time interval. It may be helpful to create an intermediate table here.
#
# Things to consider:
#
# - What type of chart will help us illustrate an association between 2 variables?
# - How can you manipulate a certain table to help generate your chart?
# - Check out the Recommended Reading for this homework!

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
birth_rates = pop.column('BIRTHS') / pop.column('2015') #calculate birth rates from 2015
death_rates = pop.column('DEATHS') / pop.column('2015') #calculate death rates from 2015
birth_death = Table().with_columns("Birth Rates", birth_rates, "Death Rates", death_rates) #create new table
birth_death.scatter("Birth Rates", "Death Rates") #create scatter plot
plt.show() #show plot

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 6.** True or False: There is an association between birth rate and death rate during this time interval.
#
# Assign `assoc` to `True` or `False` in the cell below.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
assoc = True #yes, there is an association
assoc
# Out:
# True

# %% [markdown]
# END SOLUTION

# %% [markdown]
# ## 3. Uber

# %% [markdown]
# Below we load tables containing 200,000 weekday Uber rides in the Manila, Philippines, and Boston, Massachusetts metropolitan areas from the [Uber Movement](https://movement.uber.com) project. The `sourceid` and `dstid` columns contain codes corresponding to start and end locations of each ride. The `hod` column contains codes corresponding to the hour of the day the ride took place. The `ride time` column contains the length of the ride in minutes.

# %%
boston=Table.read_table("/Users/camel/Downloads/boston.csv")
manila=Table.read_table("/Users/camel/Downloads/manila.csv")
print("Boston Table")
boston.show(4)
print("Manila Table")
manila.show(4)
# Out:
# Boston Table
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>sourceid</th> <th>dstid</th> <th>hod</th> <th>ride time</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>584     </td> <td>33   </td> <td>7   </td> <td>11.866   </td>
#         </tr>
#         <tr>
#             <td>1013    </td> <td>1116 </td> <td>13  </td> <td>17.7993  </td>
#         </tr>
#         <tr>
#             <td>884     </td> <td>1190 </td> <td>22  </td> <td>19.3488  </td>
#         </tr>
#         <tr>
#             <td>211     </td> <td>364  </td> <td>1   </td> <td>1.7235   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (199996 rows omitted)</p>
# Manila Table
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>sourceid</th> <th>dstid</th> <th>hod</th> <th>ride time</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>544     </td> <td>5    </td> <td>22  </td> <td>22.8115  </td>
#         </tr>
#         <tr>
#             <td>302     </td> <td>240  </td> <td>21  </td> <td>7.02267  </td>
#         </tr>
#         <tr>
#             <td>278     </td> <td>99   </td> <td>16  </td> <td>21.6437  </td>
#         </tr>
#         <tr>
#             <td>720     </td> <td>775  </td> <td>18  </td> <td>13.0597  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (199996 rows omitted)</p>

# %% [markdown]
# **Question 1.** Produce a histogram that visualizes the distributions of all ride times in Boston using the given bins in `equal_bins`.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
equal_bins = np.arange(0, 120, 5)
ride_times = boston.column('ride time') #gather ride time data
plt.hist(ride_times, bins=equal_bins, edgecolor='black') #plot histogram using specified bins
#adding labels and title
plt.xlabel('Ride Time (minutes)')
plt.ylabel('Percent per Minutes')
plt.title('Distribution of Ride Times in Boston')
plt.show() #show plot

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 2.** Now, produce a histogram that visualizes the distribution of all ride times in Manila using the given bins.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
equal_bins = np.arange(0, 120, 5)
ride_times2 = manila.column('ride time') #gather ride time data
plt.hist(ride_times2, bins=equal_bins, edgecolor='black') #plot histogram using specified bins
#adding labels and title
plt.xlabel('Ride Time (minutes)')
plt.ylabel('Percent per Minutes')
plt.title('Distribution of Ride Times in Manila')
plt.show() #show plot

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 3.** Let's take a closer look at the y-axis label. Assign `unit_meaning` to an integer (1, 2, 3) that corresponds to the "unit" in "Percent per unit".
#
# 1. minute
# 2. ride time
# 3. second

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
unit_meaning = 1 #the unit meaning is minutes, 1
unit_meaning #print result
# Out:
# 1

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 4.** Assign `boston_under_15` and `manila_under_15` to the percentage of rides that are less than 15 minutes in their respective metropolitan areas. Use the height variables provided below in order to compute the percentages. Your solution should only use height variables, numbers, and mathematical operations. You should **not** access the tables `boston` and `manila` in any way.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
#boston values
boston_under_5_height = 1.2
boston_5_to_under_10_height = 3.2
boston_10_to_under_15_height = 4.9

#manila values
manila_under_5_height = 0.6
manila_5_to_under_10_height = 1.4
manila_10_to_under_15_height = 2.2

boston_under_15 = boston_10_to_under_15_height = 4.9
manila_under_15 = manila_10_to_under_15_height = 2.2
boston_under_15, manila_under_15
# Out:
# (4.9, 2.2)

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 5.** Let's take a closer look at the distribution of ride times in Boston. Assign `boston_median_bin` to an integer (1, 2, 3, or 4) that corresponds to the bin that contains the median time.
#
# 1. 0-8 minutes
# 2. 8-14 minutes
# 3. 14-20 minutes
# 4. 20-40 minutes
#
# *Hint:* The median of a sorted list has half of the list elements to its left, and half to its right.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
boston_median_bin = 4 #the boston median bin is in the 20-40 min range
boston_median_bin #print result
# Out:
# 4

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 6.** Identify one difference between the histograms, in terms of the statistical properties. Can you comment on the average and/or skew of each histogram?
#
# *Hint*: The best way to do this is to compare the two histograms (from 3.1 and 3.2) visually.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %% [markdown]
# There is a large skew between the mean and median, with most of the bars being on the left. This determines that the mean is less than the median in this case. Both graphs follow this trend. One difference is that the Manila graph has minimal amounts of data on the right, while Boston has none, but the result of both charts having a higher median still stands.

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 7.** Why is your solution in Question 6 the case? Based on one of the following two readings, why are the distributions for Boston and Manila different?
#
# - [Boston reading](https://www.climatestotravel.com/climate/united-states/boston)
# - [Manila reading](https://manilafyi.com/why-is-manila-traffic-so-bad/)
#
# *Hint:* Try thinking about external factors of the two cities that may be causing the difference! There may be multiple different factors that come into play.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %% [markdown]
# Boston's main driving challenge is its weather, while Manila's main driving challenge is the sheer amount of people and traffic. Manila has the highest population density in the world, meaning that driving can be challenging due to how many people there are on the road at once. Meanwhile, Boston's weather can be unpredictable, ranging from violent snowstorms to intense heat, causing driving in the conditions to be incredibly challenging. Overall, Uber use is prevalent for both of these reasons in the respective cities.

# %% [markdown]
# END SOLUTION

# %% [markdown]
# ## 4. Histograms

# %% [markdown]
# Consider the following scatter plot:
#
# ![image.png](attachment:2d1a143d-258b-49b7-b4ce-6f48ac46f2d7.png)![image.png](attachment:29f80e18-af14-4125-801b-e771cf556d49.png)
#
# The axes of the plot represent values of two variables: $x$ and $y$.

# %% [markdown]
# Suppose we have a table called `t` that has two columns in it:
#
# - `x`: a column containing the x-values of the points in the scatter plot
# - `y`: a column containing the y-values of the points in the scatter plot

# %% [markdown]
# Below, you are given three histograms—one corresponds to column `x`, one corresponds to column `y`, and one does not correspond to either column.

# %% [markdown]
# **Histogram A:**
# ![image.png](attachment:93980fe3-38e1-4337-97e1-ec347007b4cd.png)![image.png](attachment:e5e06d1b-707c-4d34-9269-f2620d113efa.png)
#
# **Histogram B:**
# ![image.png](attachment:cbff9489-2e6e-497c-979e-313fdcccf350.png)![image.png](attachment:f11907ac-1071-46f3-8ba5-1b0b2044613a.png)
#
# **Histogram C:**
# ![image.png](attachment:5fa0a603-0554-4a81-977d-c0b65a0ab8b0.png)![image.png](attachment:c4d5803d-ca34-4a77-b0e8-43cb03de6da8.png)

# %% [markdown]
# **Question 1.** Suppose we run `t.hist('x')`. Which histogram does this code produce? Assign `histogram_column_x` to either 1, 2, or 3.
#
# 1. Histogram A
# 2. Histogram B
# 3. Histogram C

# %% [raw]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
histogram_column_x = 1 #assigns variable to answer 1
histogram_column_x #print result
# Out:
# 1

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 2.** State at least one reason why you chose the histogram from Question 1. **Make sure to clearly indicate which histogram you selected** (ex: "I chose histogram A because ...").

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %% [markdown]
# I chose histogram A as its data is more centralized. Its points align at the middle, creating the greatest data overlap of the set, then splits off to both the left and right.

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 3.** Suppose we run `t.hist('y')`. Which histogram does this code produce? Assign `histogram_column_y` to either 1, 2, or 3.
#
# 1. Histogram A
# 2. Histogram B
# 3. Histogram C

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
histogram_column_y = 2
histogram_column_y
# Out:
# 2

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 4.** State at least one reason why you chose the histogram from Question 3.  **Make sure to clearly indicate which histogram you selected** (ex: "I chose histogram A because ...").

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %% [markdown]
# I chose histogram B. Histogram B, unlike histogram A, does not have any data overlap in the center and almost seems to be an inverse of A. By process of elimination, as C depicts a data set with both x and y values by looking at how its data is spread, the most logical answer is histogram B.

# %% [markdown]
# END SOLUTION

# %% [markdown]
# You're done with Homework 3!
