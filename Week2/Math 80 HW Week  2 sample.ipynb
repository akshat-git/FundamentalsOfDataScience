# %% [markdown]
# # Homework 2: Arrays and Tables
#
# Please complete this notebook by filling in the cells provided.

# %% [markdown]
# **Helpful Resource:**
# - [Python Reference](http://data8.org/sp22/python-reference.html): Cheat sheet of helpful array & table methods.
#
# **Recommended Readings:**
# - [Arrays](https://inferentialthinking.com/chapters/05/1/Arrays.html)
# - [What is Data Science?](http://www.inferentialthinking.com/chapters/01/what-is-data-science.html)
# - [Causality and Experiments](http://www.inferentialthinking.com/chapters/02/causality-and-experiments.html)
# - [Programming in Python](http://www.inferentialthinking.com/chapters/03/programming-in-python.html)
#
# For all problems that you must write explanations and sentences for, you **must** provide your answer in the designated space. Moreover, throughout this homework and all future ones, **please be sure to not re-assign variables throughout the notebook!** For example, if you use `max_temperature` in your answer to one question, do not reassign it later on. Otherwise, you will fail tests that you thought you were passing previously!
#
#
#
# Directly sharing answers is not okay, but discussing problems with the course staff or with other students is encouraged. Refer to the policies page to learn more about how to learn cooperatively.
#
# You should start early so that you have time to get help if you're stuck.

# %% [markdown]
# ## 1. Creating Arrays

# %%
# Run this cell to set up the notebook, but please don't change it.

import numpy as np
from datascience import *
import warnings
warnings.simplefilter('ignore', FutureWarning)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Run this cell to set up the notebook, but please don't change it.
# ----> 3 import numpy as np
#       4 from datascience import *
#       5 import warnings
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# **Question 1.** Make an array called `weird_numbers` containing the following numbers (in the given order)
#
# 1. -2
# 2. the floor of 12.6
# 3. 3
# 4. 5 to the power of the ceil of 5.3
#
# *Hint:* `floor` and `ceil` are functions in the `math` module.
#
# *Note:* Python lists are different/behave differently than NumPy arrays. In Math 80, we use NumPy arrays, so please make an **array**, not a Python list.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
import math #import math library
weird_numbers = make_array([-2, math.floor(12.6), 3, 5**math.ceil(5.3)]) #set values in array
print(weird_numbers) #prints results
# Out:
# [[-2 12 3 15625]]

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 2.** Make an array called `book_title_words` containing the following three strings: "Eats", "Shoots", and "and Leaves".

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
book_title_words = np.array(["Eats", "Shoots", "and Leaves"]) #stores strings for array
title_with_commas = ", ".join(book_title_words) #joins words together
title_with_commas #displays result
# Out:
# 'Eats, Shoots, and Leaves'

# %% [markdown]
# END SOLUTION

# %% [markdown]
# Strings have a method called `join`.  `join` takes one argument, an array of strings.  It returns a single string.  Specifically, the value of `a_string.join(an_array)` is a single string that's the [concatenation](https://en.wikipedia.org/wiki/Concatenation) ("putting together") of all the strings in `an_array`, **except** `a_string` is inserted in between each string.
#
# **Question 3.** Use the array `book_title_words` and the method `join` to make two strings
#
# 1. "Eats, Shoots, and Leaves" (call this one `with_commas`)
# 2. "Eats Shoots and Leaves" (call this one `without_commas`)

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
book_title_words = np.array(["Eats", "Shoots", "and Leaves"]) #stores strings
title_without_commas = " ".join(book_title_words) #joins title without commas
print(title_with_commas) #prints eats, shoots, and leaves
print(title_without_commas) #prints eats shoots and leaves
# Out:
# Eats, Shoots, and Leaves
# Eats Shoots and Leaves

# %% [markdown]
# END SOLUTION

# %% [markdown]
# ## 2. Indexing Arrays

# %% [markdown]
# These exercises give you practice accessing individual elements of arrays.  In Python (and in many programming languages), each element is accessed by its *index*; for example, the first element is the element at index 0. Indices must be **integers**.
#
# ***Note:* If you have previous coding experience, you may be familiar with bracket notation. DO NOT use bracket notation when indexing (i.e. `arr[0]`), as this can yield different data type outputs than what we will be expecting. This can cause you to fail an autograder test.**
#
# Be sure to refer to the [Python Reference](http://data8.org/sp22/python-reference.html) on the website if you feel stuck!

# %% [markdown]
# **Question 1.** In the cell below create an array of some numbers.  Set `third_element` to the third element of `some_numbers`.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
some_numbers = make_array(0, 1, 2, 3) #set values of array
third_element = some_numbers[2] #call the third element
print(third_element) #print result
# Out:
# 2

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 2.** The next cell creates a table that displays some information about the elements of `some_numbers` and their order.  Run the cell to see the partially-completed table, then fill in the missing information (the cells that say "Ellipsis") by assigning `blank_a`, `blank_b`, `blank_c`, and `blank_d` to the correct elements in the table.
#
# *Hint:* Replace the `...` with strings or numbers. As a reminder, indices should be **integers**.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
some_numbers = [0, 1, 2, 3] #create list
table = Table().with_columns('Order', [1, 2, 3, 4],'Number', some_numbers) #create a table
table.show() #show table
blank_a = some_numbers[0] #shows first element
blank_b = some_numbers[1] #shows second element
blank_c = some_numbers[2] #shows third element
blank_d = some_numbers[3] #shows fourth element
print("blank_a:", blank_a) #print the value of blank_a
print("blank_b:", blank_b) #print the value of blank_b
print("blank_c:", blank_c) #print the value of blank_c
print("blank_d:", blank_d) #print the value of blank_d
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Order</th> <th>Number</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1    </td> <td>0     </td>
#         </tr>
#         <tr>
#             <td>2    </td> <td>1     </td>
#         </tr>
#         <tr>
#             <td>3    </td> <td>2     </td>
#         </tr>
#         <tr>
#             <td>4    </td> <td>3     </td>
#         </tr>
#     </tbody>
# </table>
# blank_a: 0
# blank_b: 1
# blank_c: 2
# blank_d: 3

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 3.** You'll sometimes want to find the **last** element of an array.  Suppose an array has 142 elements.  What is the index of its last element?

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
num_elements = 142 #initial amount of elements
last_index = num_elements - 1 #subtract 1 as indices are zero-based
print(last_index) #show result
# Out:
# 141

# %% [markdown]
# END SOLUTION

# %% [markdown]
# More often, you don't know the number of elements in an array, its *length*.  (For example, it might be a large dataset you found on the Internet.)  The function `len` takes a single argument, an array, and returns an integer that represents the `len`gth of that array.
#
# **Question 4.** The cell below loads an array called `president_birth_years`.  Calling `tbl.column(...)` on a table returns an array of the column specified, in this case the `Birth Year` column of the `president_births` table. The last element in that array is the most recent among the birth years of all the deceased Presidents. Assign that year to `most_recent_birth_year`.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
president_birth_years = Table.read_table("/Users/camel/Downloads/president_births.csv") #import file
birth_years = president_birth_years.column('Birth Year') #access birth year column
most_recent_birth_year = birth_years[len(birth_years) - 1] #use len for length and subtract 1 to get last element
print(most_recent_birth_year) #print result
# Out:
# 1917

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 5.** Finally, assign `min_of_birth_years` to the minimum of the first, sixteenth, and last birth years listed in `president_birth_years`.

# %% [markdown]
# BEGIN SOLUTION. Be sure to include comments explaining your code.

# %%
president_birth_years = Table.read_table("/Users/camel/Downloads/president_births.csv") #import file
birth_years = president_birth_years.column('Birth Year') #access birth year column
first_birth_year = birth_years[0] #access first birth year
sixteenth_birth_year = birth_years[15] #access sixteenth birth year
last_birth_year = birth_years[-1] #access last birth year
min_of_birth_years = min(first_birth_year, sixteenth_birth_year, last_birth_year) #find min value of the numbers
print(min_of_birth_years) #print result
# Out:
# 1732

# %% [markdown]
# END SOLUTION

# %% [markdown]
# ## 3. Basic Array Arithmetic

# %% [markdown]
# **Question 1.** Multiply the numbers 42, -4224, 424224242, and 250 by 157. Assign each variable below such that `first_product` is assigned to the result of $42 * 157$, `second_product` is assigned to the result of $-4224 * 157$, and so on.
#
# *Note*: For this question, **don't** use arrays.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
#given numbers
firstnum = 42
secondnum = -4224
thirdnum = 424224242
fourthnum = 250
#multiply each by 157
firstproduct = firstnum * 157
secondproduct = secondnum * 157
thirdproduct = thirdnum * 157
fourthproduct = fourthnum * 157
#show results
print("First product:", firstproduct)
print("Second product:", secondproduct)
print("Third product:", thirdproduct)
print("Fourth product:", fourthproduct)
# Out:
# First product: 6594
# Second product: -663168
# Third product: 66603205994
# Fourth product: 39250

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 2.** Now, do the same calculation, but using an array called `numbers` and only a single multiplication (`*`) operator.  Store the 4 results in an array named `products`.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
numbers = make_array(42, -4224, 424224242, 250) #make the array
products = numbers * 157 #multiply all numbers by 157
print(products) #print the outcomes of the multiplication
# Out:
# [       6594     -663168 66603205994       39250]

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 3.** Oops, we made a typo!  Instead of 157, we wanted to multiply each number by 1577.  Compute the correct products in the cell below using array arithmetic.  Notice that your job is really easy if you previously defined an array containing the 4 numbers.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
numbers = make_array(42, -4224, 424224242, 250) #make the array
products = numbers * 1577 #multiply all numbers by 1577
print(products) #print the outcomes of the multiplication
# Out:
# [       66234     -6661248 669001629634       394250]

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 4.** We've loaded an array of temperatures in the next cell.  Each number is the highest temperature observed on a day at a climate observation station, mostly from the US.  Since they're from the US government agency [NOAA](https://www.noaa.gov/), all the temperatures are in Fahrenheit.
#
# Convert all the temperatures to Celsius by first subtracting 32 from them, then multiplying the results by $\frac{5}{9}$, i.e. $C = (F - 32) * \frac{5}{9}$. After converting the temperatures to Celsius, make sure to **ROUND** the final result  to the nearest integer using the `np.round` function.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
temps = make_array(25, 87, 89, 96, 79, 91, 75, 84, 70, 7) #make array using max temperatures from table
celsius_temperatures = (temps - 32) * (5 / 9) #run calculations from fahrenheit to celsius
rounded_celsius_temperatures = np.round(celsius_temperatures) #round the numbers
print(rounded_celsius_temperatures) #print results
# Out:
# [ -4.  31.  32.  36.  26.  33.  24.  29.  21. -14.]

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 5.** The cell below loads all the *lowest* temperatures from each day (in Fahrenheit).  Compute the daily temperature range for each day. That is, compute the difference between each daily maximum temperature and the corresponding daily minimum temperature.  **Pay attention to the units and give your answer in Celsius!** Make sure **NOT** to round your answer for this question!
#
# *Note:* Remember that in Question 4, `celsius_max_temperatures` was rounded, so you might not want to use that variable in this question.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
max_temperatures = np.array([25, 87, 89, 96, 79, 91, 74, 84, 70, 7]) #compute the first few max temperatures
min_temperatures = np.array([13, 69, 67, 72, 75, 81, 45, 68, 39, -7]) #compute the first few min temperatures
max_temperatures_celsius = (max_temperatures - 32) * (5 / 9) #convert maxes to celsius
min_temperatures_celsius = (min_temperatures - 32) * (5 / 9) #convert mins to celsius
temperature_range_celsius = max_temperatures_celsius - min_temperatures_celsius #compute difference
print(temperature_range_celsius) #print results
# Out:
# [  6.66666667  10.          12.22222222  13.33333333   2.22222222
#    5.55555556  16.11111111   8.88888889  17.22222222   7.77777778]

# %% [markdown]
# END SOLUTION

# %% [markdown]
# ## 4. Old Faithful

# %% [markdown]
# Old Faithful is a geyser in Yellowstone that erupts every 44 to 125 minutes (according to [Wikipedia](https://en.wikipedia.org/wiki/Old_Faithful)). People are [often told that the geyser erupts every hour](http://yellowstone.net/geysers/old-faithful/), but in fact the waiting time between eruptions is more variable. Let's take a look.

# %% [markdown]
# **Question 1.** The first line below assigns `waiting_times` to an array of 272 consecutive waiting times between eruptions, taken from a classic 1938 dataset. Assign the names `shortest`, `longest`, and `average` so that the `print` statement is correct.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
geyser = Table.read_table("/Users/camel/Downloads/old_faithful.csv") #import file
waiting_times = geyser.column('waiting') #assign the waiting times
shortest = np.min(waiting_times) #find shortest time
longest = np.max(waiting_times) #find longest time
average = np.mean(waiting_times) #find average time
print("Shortest:", shortest) #print shortest result
print("Longest:", longest) #print longest result
print("Average:", average) #print average
# Out:
# Shortest: 43
# Longest: 96
# Average: 70.8970588235

# %%
END SOLUTION

# %% [markdown]
# **Question 2.** Assign `biggest_decrease` to the biggest decrease in waiting time between two consecutive eruptions. For example, the third eruption occurred after 74 minutes and the fourth after 62 minutes, so the decrease in waiting time was 74 - 62 = 12 minutes.
#
# *Hint*: We want to return the absolute value of the biggest decrease.
#
# *Note*: `np.diff()` calculates the difference between subsequent values in an array. For example, calling `np.diff()` on the array `make_array(1, 8, 3, 5)` evaluates to `array([8 - 1, 3 - 8, 5 - 3])`, or `array([7, -5, 2])`.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
geyser = Table.read_table("/Users/camel/Downloads/old_faithful.csv") #import file
waiting_times = geyser.column('waiting') #assign waiting times
waiting_time_diff = np.diff(waiting_times) #calculate difference between times
biggest_decrease = np.max(np.abs(waiting_time_diff)) #find biggest decrease by taking max abs value of differences
print("Biggest decrease:", biggest_decrease) #print result
# Out:
# Biggest decrease: 47

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 3.** The `faithful_with_eruption_nums` table contains two columns: `eruption_number`, which represents the number of that eruption, and `waiting`, which represents the time spent waiting after that eruption. For example, take the first two rows of the table:
#
# | eruption number | waiting |
# |-----------------|---------|
# | 1               | 79      |
# | 2               | 54      |
#
# We can read this as follows: after the first eruption, we waited 79 minutes for the second eruption. Then, after the second eruption, we waited 54 minutes for the third eruption.
#
# Suppose Oscar and Wendy started watching Old Faithful at the start of the first eruption. Assume that they watch until the end of the tenth eruption. For some of that time they will be watching eruptions, and for the rest of the time they will be waiting for Old Faithful to erupt. How many minutes will they spend waiting for eruptions?
#
# *Hint #1:* One way to approach this problem is to use the `take` or `where` method on the table `faithful_with_eruption_nums`.
#
# *Hint #2:* `first_nine_waiting_times` must be an array.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
faithful_with_eruption_nums = Table.read_table("/Users/camel/Downloads/eruptions.csv") #import first nine entries from file
first_nine_waiting_times = faithful_with_eruption_nums.take(range(9)).column('waiting') #extract 9 times
total_waiting_time = sum(first_nine_waiting_times) #sum of times
print("Total waiting time for the first 9 eruptions:", total_waiting_time, "minutes") #print total time
# Out:
# Total waiting time for the first 9 eruptions: 633 minutes

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 4.** Let’s imagine your guess for the next waiting time was always just the length of the previous waiting time. If you always guessed the previous waiting time, how big would your error in guessing the waiting times be, on average?
#
# For example, since the first four waiting times are 79, 54, 74, and 62, the average difference between your guess and the actual time for just the second, third, and fourth eruptions would be $\frac{|79-54|+ |54-74|+ |74-62|}{3} = 19$.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
faithful_with_eruption_nums = Table.read_table("/Users/camel/Downloads/eruptions.csv") #import file
waiting_times = faithful_with_eruption_nums.column('waiting') #extract waiting times
errors = np.abs(np.diff(waiting_times)) #find abs differences in times
average_error = np.mean(errors) #find average error
print("Average error in guessing waiting times:", average_error) #print result
# Out:
# Average error in guessing waiting times: 22.5

# %% [markdown]
# END SOLUTION

# %% [markdown]
# ## 5. Tables

# %% [markdown]
# **Question 1.** Suppose you have 4 apples, 3 oranges, and 3 pineapples.  (Perhaps you're using Python to solve a high school Algebra problem.)  Create a table that contains this information.  It should have two columns: `fruit name` and `count`.  Assign the new table to the variable `fruits`.
#
# *Note:* Use lower-case and singular words for the name of each fruit, like `"apple"`.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
from datascience import *
fruits = Table().with_columns('Fruit name', make_array('apple','orange','pineapple'),'Count', make_array(4,3,3)) #create the table using information
fruits #display table
# Out:
# Fruit name | Count
# apple      | 4
# orange     | 3
# pineapple  | 3

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 2.** The file `inventory.csv` contains information about the inventory at a fruit stand.  Each row represents the contents of one box of fruit. Load it as a table named `inventory` using the `Table.read_table()` function. `Table.read_table(...)` takes one argument (data file name in string format) and returns a table.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
inventory = Table.read_table("/Users/camel/Downloads/inventory.csv") #imports the file
inventory #shows table
# Out:
# box ID | fruit name | count
# 53686  | kiwi       | 45
# 57181  | strawberry | 123
# 25274  | apple      | 20
# 48800  | orange     | 35
# 26187  | strawberry | 255
# 57930  | grape      | 517
# 52357  | strawberry | 102
# 43566  | peach      | 40

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 3.** Does each box at the fruit stand contain a different fruit? Set `all_different` to `True` if each box contains a different fruit or to `False` if multiple boxes contain the same fruit.
#
# *Hint:* You don't have to write code to calculate the True/False value for `all_different`. Just look at the `inventory` table and assign `all_different` to either `True` or `False` according to what you can see from the table in answering the question.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
all_different = False #looking at the table, the fruits are not all different
print(all_different) #print the answer
# Out:
# False

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 4.** The file `sales.csv` contains the number of fruit sold from each box last Saturday.  It has an extra column called `price per fruit ($)` that's the price *per item of fruit* for fruit in that box.  The rows are in the same order as the `inventory` table.  Load these data into a table called `sales`.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
sales = Table.read_table("/Users/camel/Downloads/sales.csv") #import file
sales #print table
# Out:
# box ID | fruit name | count sold | price per fruit ($)
# 53686  | kiwi       | 3          | 0.5
# 57181  | strawberry | 101        | 0.2
# 25274  | apple      | 0          | 0.8
# 48800  | orange     | 35         | 0.6
# 26187  | strawberry | 25         | 0.15
# 57930  | grape      | 355        | 0.06
# 52357  | strawberry | 102        | 0.25
# 43566  | peach      | 17         | 0.8

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 5.** How many fruits did the store sell in total on that day?

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
total_count_sold = sales.column('count sold').sum() #finds sum of count sold column
print(total_count_sold) #prints result
# Out:
# 638

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 6.** What was the store's total revenue (the total price of all fruits sold) on that day?
#
# *Hint:* If you're stuck, think first about how you would compute the total revenue from just the grape sales.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
revenue = sales.column('price per fruit ($)').sum() #finds sum of price per fruit column
print(revenue) #prints result
# Out:
# 3.36

# %% [markdown]
# END SOLUTION

# %% [markdown]
# **Question 7.** Make a new table called `remaining_inventory`.  It should have the same rows and columns as `inventory`, except that the amount of fruit sold from each box should be subtracted from that box's **original** count, so that the `count` column is **updated to be** the amount of fruit remaining after Saturday.

# %% [markdown]
# Type your solution in the following cell. Be sure to include comments explaining your code.

# %%
inventory = Table().with_columns('Fruit', ['Kiwi', 'Strawberry', 'Apple', 'Orange', 'Grape', 'Peach'], 'Original Count', [45, 480, 20, 35, 517, 40]) #create table
updated_counts = [45 - 3, 480 - 228, 20 - 0, 35 - 35, 517 - 355, 40 - 17] #subtract what was sold from original total
remaining_inventory = inventory.with_columns('Remaining Count After Saturday', updated_counts) #add remaining count column
remaining_inventory.show() #print new table
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Fruit</th> <th>Original Count</th> <th>Remaining Count After Saturday</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Kiwi      </td> <td>45            </td> <td>42                            </td>
#         </tr>
#         <tr>
#             <td>Strawberry</td> <td>480           </td> <td>252                           </td>
#         </tr>
#         <tr>
#             <td>Apple     </td> <td>20            </td> <td>20                            </td>
#         </tr>
#         <tr>
#             <td>Orange    </td> <td>35            </td> <td>0                             </td>
#         </tr>
#         <tr>
#             <td>Grape     </td> <td>517           </td> <td>162                           </td>
#         </tr>
#         <tr>
#             <td>Peach     </td> <td>40            </td> <td>23                            </td>
#         </tr>
#     </tbody>
# ...

# %% [markdown]
# END SOLUTION

# %% [markdown]
# You're done with Homework 2!
